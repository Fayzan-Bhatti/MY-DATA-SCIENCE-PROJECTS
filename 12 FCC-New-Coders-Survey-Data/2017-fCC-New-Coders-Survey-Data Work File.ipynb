# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_seq_items=None

# %% [markdown]
# * We have to lounch a new E learning course in differnet country and monthly charges are 60 dollar. but use 59 as because it affect schologycal affect concept in economice use 499 not 500
# * Data is 2017 and in 2017 mostly mobile and web is mostly use.
# * Dedtuct the market buying power means people in the market will accept our this new course or nor

# %%
pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv")
# Out:
# C:\Users\junaid.8646059\Junaid\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (17,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0      27.0               0.0             NaN                NaN          NaN
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18170  41.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# ...

# %%
data=pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv",low_memory=False)
data.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# ...

# %%
data.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# count  15367.000000      17709.000000     1069.000000        1079.000000
# mean      27.691872          0.062002        0.699719           0.305839
# std        8.559239          0.241167        0.458594           0.460975
# min        0.000000          0.000000        0.000000           0.000000
# 25%       22.000000          0.000000        0.000000           0.000000
# 50%       26.000000          0.000000        1.000000           0.000000
# 75%       32.000000          0.000000        1.000000           1.000000
# max       90.000000          1.000000        1.000000           1.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventConferences  \
# count        1073.000000     2314.000000                1609.0
# mean            0.818267        1.832325                   1.0
# std             0.385805        0.972813                   0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18175 entries, 0 to 18174
# Columns: 136 entries, Age to YouTubeTheNewBoston
# dtypes: float64(105), object(31)
# memory usage: 18.9+ MB

# %%
data.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
# ...

# %%
pd.set_option("max_seq_items",None)

# %%
data.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
# ...

# %%
len(data.columns)
# Out:
# 136

# %%
data.shape
# Out:
# (18175, 136)

# %%
data["JobRoleInterest"].unique()
#people have multiple interest as well
# Out:
# array([nan, 'Full-Stack Web Developer',
#        '  Front-End Web Developer, Back-End Web Developer,   DevOps / SysAdmin,   Mobile Developer, Full-Stack Web Developer',
#        ...,
#        '  Data Scientist, Game Developer,   Quality Assurance Engineer',
#        'Back-End Web Developer, Data Engineer,   Data Scientist,   DevOps / SysAdmin',
#        '  DevOps / SysAdmin,   Mobile Developer,   Product Manager, Game Developer,   Front-End Web Developer, Data Engineer,   Quality Assurance Engineer,   User Experience Designer, Back-End Web Developer,   Data Scientist, Full-Stack Web Developer, Information Security, IT specialist '],
#       dtype=object)

# %%
data["JobRoleInterest"].value_counts()
# Out:
# Full-Stack Web Developer                                                                                                                            823
#   Front-End Web Developer                                                                                                                           450
#   Data Scientist                                                                                                                                    152
# Back-End Web Developer                                                                                                                              142
#   Mobile Developer                                                                                                                                  117
#                                                                                                                                                    ...
# ...

# %%
data["JobRoleInterest"].value_counts(normalize=True)*100
#our data is representive because it represent the population and sample and our problem as well
# Out:
# Full-Stack Web Developer                                                                                                                            11.770595
#   Front-End Web Developer                                                                                                                            6.435927
#   Data Scientist                                                                                                                                     2.173913
# Back-End Web Developer                                                                                                                               2.030892
#   Mobile Developer                                                                                                                                   1.673341
#                                                                                                                                                       ...
# ...

# %% [markdown]
# # i can split the data to check the which is the percent in data people is more interested

# %%
data["JobRoleInterest"].str.split(",")
# Out:
# 0                                                      NaN
# 1                               [Full-Stack Web Developer]
# 2        [  Front-End Web Developer,  Back-End Web Deve...
# 3        [  Front-End Web Developer,  Full-Stack Web De...
# 4        [Full-Stack Web Developer,  Information Securi...
#                                ...
# 18170                                                  NaN
# 18171    [  DevOps / SysAdmin,    Mobile Developer,    ...
# 18172                                                  NaN
# 18173                                                  NaN
# 18174    [Back-End Web Developer,  Data Engineer,    Da...
# Name: JobRoleInterest, Length: 18175, dtype: object

# %% [markdown]
# # count the list

# %%
def count_list(lst):
    return len(lst)

# %%
count_list(["ali","usman","hasan"])
# Out:
# 3

# %%
data["JobRoleInterest"].str.split(",").map(count_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ef29a141b2ad> in <module>
# ----> 1 data["JobRoleInterest"].str.split(",").map(count_list)
#
# ~\Junaid\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~\Junaid\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-888e61c89178> in count_list(lst)
#       1 def count_list(lst):
# ...

# %%
data["JobRoleInterest"].isnull().sum()
#so we have missing data

# %%
data["JobRoleInterest"].dropna()
# Out:
# 1                                 Full-Stack Web Developer
# 2          Front-End Web Developer, Back-End Web Develo...
# 3          Front-End Web Developer, Full-Stack Web Deve...
# 4        Full-Stack Web Developer, Information Security...
# 6                                 Full-Stack Web Developer
#                                ...
# 18161                             Full-Stack Web Developer
# 18162      Data Scientist, Game Developer,   Quality As...
# 18163    Back-End Web Developer, Data Engineer,   Data ...
# 18171      DevOps / SysAdmin,   Mobile Developer,   Pro...
# 18174    Back-End Web Developer, Data Engineer,   Data ...
# Name: JobRoleInterest, Length: 6992, dtype: object

# %%
data["JobRoleInterest"].dropna().str.split(",").map(count_list)
# Out:
# 1         1
# 2         5
# 3         3
# 4         5
# 6         1
#          ..
# 18161     1
# 18162     3
# 18163     4
# 18171    13
# 18174     3
# Name: JobRoleInterest, Length: 6992, dtype: int64

# %%
data["JobRoleInterest"].dropna().str.split(",").map(count_list).value_counts()
#1sy method
# Out:
# 1     2213
# 3     1111
# 4     1064
# 5      842
# 2      761
# 6      470
# 7      270
# 8      123
# 9       69
# 10      33
# 12      21
# 11      13
# 13       2
# Name: JobRoleInterest, dtype: int64

# %%
data["JobRoleInterest"].dropna().str.split(",").str.len()
#2nd method
# Out:
# 1         1
# 2         5
# 3         3
# 4         5
# 6         1
#          ..
# 18161     1
# 18162     3
# 18163     4
# 18171    13
# 18174     3
# Name: JobRoleInterest, Length: 6992, dtype: int64

# %%
data["JobRoleInterest"].dropna().str.split(",").str.len().value_counts()
#2nd method
# Out:
# 1     2213
# 3     1111
# 4     1064
# 5      842
# 2      761
# 6      470
# 7      270
# 8      123
# 9       69
# 10      33
# 12      21
# 11      13
# 13       2
# Name: JobRoleInterest, dtype: int64

# %% [markdown]
# # we are interested in mobile and web app

# %%
interest="Web Developer","Mobile Developer"

# %%
type(interest)
# Out:
# tuple

# %%
data["JobRoleInterest"].isin(["  Data Scientist"]).sum()
# Out:
# 152

# %%
data["JobRoleInterest"].iloc[11]
# Out:
# '  DevOps / SysAdmin,   Data Scientist, Information Security, Data Engineer'

# %%
data["JobRoleInterest"].isin(["Web Developer","Mobile Developer"]).sum()
# Out:
# 0

# %%
data["JobRoleInterest"].str.contains("Web Developer|Mobile Developer")
# Out:
# 0         NaN
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18170     NaN
# 18171    True
# 18172     NaN
# 18173     NaN
# 18174    True
# Name: JobRoleInterest, Length: 18175, dtype: object

# %%
data["JobRoleInterest"].str.contains("Web Developer|Mobile Developer").sum()
# Out:
# 6030

# %%
not_null=data["JobRoleInterest"].dropna()

# %%
not_null.shape
# Out:
# (6992,)

# %%
not_null.str.contains("Web Developer|Mobile Developer").sum()
# Out:
# 6030

# %%
not_null.str.contains("Web Developer|Mobile Developer").value_counts()
# Out:
# True     6030
# False     962
# Name: JobRoleInterest, dtype: int64

# %%
representation=not_null.str.contains("Web Developer|Mobile Developer").value_counts(normalize=True)*100
representation
# Out:
# True     86.241419
# False    13.758581
# Name: JobRoleInterest, dtype: float64

# %%
representation.plot.bar()
# Out:
# <AxesSubplot:>

# %%
representation.plot.pie()
# Out:
# <AxesSubplot:ylabel='JobRoleInterest'>

# %%
representation.plot.pie(autopct="%0.1f%%")
# Out:
# <AxesSubplot:ylabel='JobRoleInterest'>

# %%
representation.plot.pie(autopct="%0.1f%%")
plt.legend()

# %%
data["JobRoleInterest"]
# Out:
# 0                                                      NaN
# 1                                 Full-Stack Web Developer
# 2          Front-End Web Developer, Back-End Web Develo...
# 3          Front-End Web Developer, Full-Stack Web Deve...
# 4        Full-Stack Web Developer, Information Security...
#                                ...
# 18170                                                  NaN
# 18171      DevOps / SysAdmin,   Mobile Developer,   Pro...
# 18172                                                  NaN
# 18173                                                  NaN
# 18174    Back-End Web Developer, Data Engineer,   Data ...
# Name: JobRoleInterest, Length: 18175, dtype: object

# %%
data["JobRoleInterest"].notnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18170    False
# 18171     True
# 18172    False
# 18173    False
# 18174     True
# Name: JobRoleInterest, Length: 18175, dtype: bool

# %%
fcc=data[data["JobRoleInterest"].notnull()]
fcc.copy()
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18163  57.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
# ...

# %%
fcc.shape
# Out:
# (6992, 136)

# %% [markdown]
# # find the location

# %%
fcc.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
# ...

# %%
"country" in fcc.columns
# Out:
# False

# %%
import re
#regular expression

# %%
fcc.columns[fcc.columns.str.contains("country",flags=re.I)]
# I is ignore case , i can use cou just it will get out result
# Out:
# Index(['CountryCitizen', 'CountryLive'], dtype='object')

# %% [markdown]
# # so we dicied "CountryLive" for future analysis

# %%
fcc.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls', 'CodeEventFCC',
#        'CodeEventGameJam', 'CodeEventGirlDev', 'CodeEventHackathons',
#        'CodeEventMeetup', 'CodeEventNodeSchool', 'CodeEventNone',
#        'CodeEventOther', 'CodeEventRailsBridge', 'CodeEventRailsGirls',
#        'CodeEventStartUpWknd', 'CodeEventWkdBootcamps', 'CodeEventWomenCode',
#        'CodeEventWorkshops', 'CommuteTime', 'CountryCitizen', 'CountryLive',
#        'EmploymentField', 'EmploymentFieldOther', 'EmploymentStatus',
#        'EmploymentStatusOther', 'ExpectedEarning', 'FinanciallySupporting',
#        'FirstDevJob', 'Gender', 'GenderOther', 'HasChildren', 'HasDebt',
#        'HasFinancialDependents', 'HasHighSpdInternet', 'HasHomeMortgage',
#        'HasServedInMilitary', 'HasStudentDebt', 'HomeMortgageOwe',
# ...

# %% [markdown]
# # here is MonthsProgramming colum , we find per month subscribtion

# %%
fcc["MonthsProgramming"]
# Out:
# 1         6.0
# 2         5.0
# 3         5.0
# 4        24.0
# 6        12.0
#          ...
# 18161     6.0
# 18162    84.0
# 18163     NaN
# 18171     1.0
# 18174    10.0
# Name: MonthsProgramming, Length: 6992, dtype: float64

# %%
fcc["MonthsProgramming"].isnull().sum()
# Out:
# 359

# %%
fcc["MonthsProgramming"].value_counts()
#here is zero=235 which make our calculation fasle so, we convert this zero into 1 because person with 0 also have some experiece
# Out:
# 1.0      767
# 2.0      669
# 6.0      654
# 3.0      637
# 12.0     616
#         ...
# 49.0       1
# 171.0      1
# 198.0      1
# 105.0      1
# 51.0       1
# Name: MonthsProgramming, Length: 91, dtype: int64

# %%
fcc["MonthsProgramming"].value_counts().sort_index()
# Out:
# 0.0      235
# 1.0      767
# 2.0      669
# 3.0      637
# 4.0      367
#         ...
# 360.0      5
# 370.0      1
# 408.0      1
# 480.0      2
# 744.0      4
# Name: MonthsProgramming, Length: 91, dtype: int64

# %%
fcc["MonthsProgramming"].str.replace("0.0","1")
#this is not a string so we apply directly
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-97f9be6095b6> in <module>
# ----> 1 fcc["MonthsProgramming"].str.replace("0.0","1")
#       2 #this is not a string so we apply directly
#
# ~\Junaid\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Junaid\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
fcc["MonthsProgramming"].replace(0.0,1).value_counts()

# %%
fcc["MonthsProgramming"]=fcc["MonthsProgramming"].replace(0,1)
# Out:
# <ipython-input-54-9aa4654a1794>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fcc["MonthsProgramming"]=fcc["MonthsProgramming"].replace(0,1)

# %%
fcc["MonthsProgramming"]
#there is also null values
# Out:
# 1         6.0
# 2         5.0
# 3         5.0
# 4        24.0
# 6        12.0
#          ...
# 18161     6.0
# 18162    84.0
# 18163     NaN
# 18171     1.0
# 18174    10.0
# Name: MonthsProgramming, Length: 6992, dtype: float64

# %%
fcc["MonthsProgramming"].isnull().sum()
# Out:
# 359

# %%
bol=fcc["MonthsProgramming"].isnull()
bol
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 6        False
#          ...
# 18161    False
# 18162    False
# 18163     True
# 18171    False
# 18174    False
# Name: MonthsProgramming, Length: 6992, dtype: bool

# %%
fcc.loc[bol,["MonthsProgramming","MoneyForLearning"]]
# Out:
#        MonthsProgramming  MoneyForLearning
# 13                   NaN               NaN
# 29                   NaN             300.0
# 34                   NaN               NaN
# 37                   NaN               NaN
# 100                  NaN               NaN
# ...                  ...               ...
# 17727                NaN              50.0
# 17862                NaN               NaN
# 18052                NaN             500.0
# 18129                NaN               0.0
# 18163                NaN               0.0
#
# [359 rows x 2 columns]

# %%
fcc.loc[bol,["MonthsProgramming","MoneyForLearning"]].shape
# Out:
# (359, 2)

# %%
len(fcc.loc[bol,"MoneyForLearning"])
# Out:
# 359

# %%
fcc.loc[bol,"MoneyForLearning"].notnull().sum()
#data is avaiable here
# Out:
# 159

# %%
fcc.shape
# Out:
# (6992, 136)

# %%
fcc["MonthsProgramming"]
# Out:
# 1         6.0
# 2         5.0
# 3         5.0
# 4        24.0
# 6        12.0
#          ...
# 18161     6.0
# 18162    84.0
# 18163     NaN
# 18171     1.0
# 18174    10.0
# Name: MonthsProgramming, Length: 6992, dtype: float64

# %%
fcc[fcc["MonthsProgramming"].notnull()]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18160  62.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
# ...

# %%
fcc[fcc["MonthsProgramming"].notnull()]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18160  62.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
# ...

# %%
fcc[fcc["MonthsProgramming"].notnull()].shape
# Out:
# (6633, 136)

# %%
fcc1=fcc[fcc["MonthsProgramming"].notnull()]

# %%
fcc1.shape
# Out:
# (6633, 136)

# %% [markdown]
# # making new column with monthly exp

# %%
fcc1["MoneyForLearning"]
# Out:
# 1           80.0
# 2         1000.0
# 3            0.0
# 4            0.0
# 6            0.0
#           ...
# 18160      100.0
# 18161        0.0
# 18162        0.0
# 18171    10000.0
# 18174        NaN
# Name: MoneyForLearning, Length: 6633, dtype: float64

# %%
fcc1["MonthsProgramming"]
# Out:
# 1         6.0
# 2         5.0
# 3         5.0
# 4        24.0
# 6        12.0
#          ...
# 18160     3.0
# 18161     6.0
# 18162    84.0
# 18171     1.0
# 18174    10.0
# Name: MonthsProgramming, Length: 6633, dtype: float64

# %%
fcc1["MoneyForLearning"]/fcc1["MonthsProgramming"]
# Out:
# 1           13.333333
# 2          200.000000
# 3            0.000000
# 4            0.000000
# 6            0.000000
#              ...
# 18160       33.333333
# 18161        0.000000
# 18162        0.000000
# 18171    10000.000000
# 18174             NaN
# Length: 6633, dtype: float64

# %%
fcc1["Monthly_exp"]=fcc1["MoneyForLearning"]/fcc1["MonthsProgramming"]
# Out:
# <ipython-input-72-9037ec84f03c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fcc1["Monthly_exp"]=fcc1["MoneyForLearning"]/fcc1["MonthsProgramming"]

# %%
fcc1["Monthly_exp"]
# Out:
# 1           13.333333
# 2          200.000000
# 3            0.000000
# 4            0.000000
# 6            0.000000
#              ...
# 18160       33.333333
# 18161        0.000000
# 18162        0.000000
# 18171    10000.000000
# 18174             NaN
# Name: Monthly_exp, Length: 6633, dtype: float64

# %%
fcc1.groupby("CountryLive")["Monthly_exp"].mean()
# Out:
# CountryLive
# Afghanistan                 0.000000
# Albania                     7.111111
# Algeria                     0.000000
# Angola                    116.666667
# Anguilla                    0.000000
#                             ...
# Venezuela                  11.923077
# Vietnam                   243.324074
# Virgin Islands (USA)       60.416667
# Yemen                   10000.000000
# Zimbabwe                   23.125000
# Name: Monthly_exp, Length: 136, dtype: float64

# %%
fcc1.groupby("CountryLive")["Monthly_exp"].mean().sort_values()
# Out:
# CountryLive
# Afghanistan            0.0
# Vanuatu                0.0
# Turkmenistan           0.0
# Samoa                  0.0
# Netherland Antilles    0.0
#                       ...
# Aruba                  NaN
# Bolivia                NaN
# Liberia                NaN
# Panama                 NaN
# Qatar                  NaN
# Name: Monthly_exp, Length: 136, dtype: float64

# %%
fcc1.groupby("CountryLive")["Monthly_exp"].mean().sort_values(ascending=False)
# Out:
# CountryLive
# Yemen          10000.000000
# Puerto Rico     4291.394558
# Austria          936.208333
# Spain            784.553084
# Jamaica          747.037037
#                    ...
# Aruba                   NaN
# Bolivia                 NaN
# Liberia                 NaN
# Panama                  NaN
# Qatar                   NaN
# Name: Monthly_exp, Length: 136, dtype: float64

# %%
fcc1["MoneyForLearning"].max()
# Out:
# 200000.0

# %%
fcc1["MoneyForLearning"].min()
# Out:
# 0.0

# %%
fcc1["CountryLive"].notnull().sum()
# Out:
# 6519

# %%
fcc1["CountryLive"].isnull().sum()
# Out:
# 114

# %%
fcc1["CountryLive"].shape
# Out:
# (6633,)

# %%
6519+114
# Out:
# 6633

# %%
fcc1["CountryLive"].isna().sum()
# Out:
# 114

# %%
fcc1["CountryLive"].value_counts()
# Out:
# United States of America    2998
# India                        503
# United Kingdom               296
# Canada                       252
# Poland                       125
#                             ...
# Qatar                          1
# Somalia                        1
# Cameroon                       1
# Angola                         1
# Nambia                         1
# Name: CountryLive, Length: 136, dtype: int64

# %% [markdown]
# **so decided that we will go first 4 country because in 1st foure they can speek english and we are going to louch english e learning course, so we filter data**

# %%
fcc1["CountryLive"].value_counts().index
# Out:
# Index(['United States of America', 'India', 'United Kingdom', 'Canada',
#        'Poland', 'Brazil', 'Germany', 'Australia', 'Russia', 'Ukraine',
#        'Nigeria', 'Spain', 'France', 'Romania',
#        'Netherlands (Holland, Europe)', 'Italy', 'Philippines', 'Serbia',
#        'Ireland', 'Greece', 'South Africa', 'Mexico', 'Turkey', 'Hungary',
#        'Singapore', 'Norway', 'Argentina', 'Croatia', 'Pakistan',
#        'New Zealand', 'Sweden', 'Denmark', 'Indonesia', 'China', 'Egypt',
#        'Finland', 'Vietnam', 'Malaysia', 'Czech Republic', 'Kenya', 'Portugal',
#        'Israel', 'Japan', 'Lithuania', 'Bangladesh', 'Great Britain',
#        'Bosnia & Herzegovina', 'Belarus', 'Belgium', 'United Arab Emirates',
#        'Korea South', 'Nepal', 'Austria', 'Colombia', 'Venezuela',
#        'Switzerland', 'Republic of Serbia', 'Bulgaria', 'Taiwan', 'Latvia',
#        'Ghana', 'Thailand', 'Hong Kong', 'Macedonia', 'Kazakhstan', 'Jamaica',
# ...

# %%
country=['United States of America', 'India', 'United Kingdom', 'Canada']

# %%
bol=fcc1["CountryLive"].isin(country)
bol
# Out:
# 1         True
# 2         True
# 3        False
# 4        False
# 6         True
#          ...
# 18160    False
# 18161    False
# 18162    False
# 18171    False
# 18174     True
# Name: CountryLive, Length: 6633, dtype: bool

# %%
fcc1[bol]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 1      34.0               0.0             NaN                NaN
# 2      21.0               0.0             NaN                NaN
# 6      29.0               0.0             NaN                NaN
# 14     27.0               1.0             1.0                0.0
# 15     32.0               0.0             NaN                NaN
# ...     ...               ...             ...                ...
# 18111  30.0               0.0             NaN                NaN
# 18113  24.0               0.0             NaN                NaN
# 18130  23.0               0.0             NaN                NaN
# 18156  29.0               0.0             NaN                NaN
# 18174  50.0               0.0             NaN                NaN
#
#        BootcampName  BootcampRecommend  ChildrenNumber  \
# 1               NaN                NaN             NaN
# 2               NaN                NaN             NaN
# ...

# %%
fcc1_update=fcc1[bol]
fcc1_update
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 1      34.0               0.0             NaN                NaN
# 2      21.0               0.0             NaN                NaN
# 6      29.0               0.0             NaN                NaN
# 14     27.0               1.0             1.0                0.0
# 15     32.0               0.0             NaN                NaN
# ...     ...               ...             ...                ...
# 18111  30.0               0.0             NaN                NaN
# 18113  24.0               0.0             NaN                NaN
# 18130  23.0               0.0             NaN                NaN
# 18156  29.0               0.0             NaN                NaN
# 18174  50.0               0.0             NaN                NaN
#
#        BootcampName  BootcampRecommend  ChildrenNumber  \
# 1               NaN                NaN             NaN
# 2               NaN                NaN             NaN
# ...

# %%
fcc1_update.groupby("CountryLive")["Monthly_exp"].mean().sort_values(ascending=False)
# Out:
# CountryLive
# United States of America    227.997996
# India                       135.100982
# Canada                      113.510961
# United Kingdom               45.534443
# Name: Monthly_exp, dtype: float64

# %% [markdown]
# **mean each above country spend average amount**

# %% [markdown]
# # check the outlier in data, we draw box plot on continous data

# %%
sns.boxplot(x="CountryLive",y="Monthly_exp",data=fcc1_update)
#x mean it will group the country , y mean draw on monthly_exp
# Out:
# <AxesSubplot:xlabel='CountryLive', ylabel='Monthly_exp'>

# %% [markdown]
# # so remove the outlier

# %%
country
# Out:
# ['United States of America', 'India', 'United Kingdom', 'Canada']

# %%
fcc1_update["CountryLive"]=="United States of America"
# Out:
# 1         True
# 2         True
# 6        False
# 14        True
# 15        True
#          ...
# 18111    False
# 18113     True
# 18130     True
# 18156    False
# 18174    False
# Name: CountryLive, Length: 4049, dtype: bool

# %%
bol=fcc1_update["Monthly_exp"]<20000
bol
# Out:
# 1         True
# 2         True
# 6         True
# 14       False
# 15        True
#          ...
# 18111     True
# 18113     True
# 18130     True
# 18156     True
# 18174    False
# Name: Monthly_exp, Length: 4049, dtype: bool

# %%
fcc1_update[bol]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
# ...

# %%
fcc1_update=fcc1_update[bol]

# %%
fcc1_update
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
# ...

# %%
fcc1_update.groupby("CountryLive")["Monthly_exp"].mean().sort_values(ascending=False)
# Out:
# CountryLive
# United States of America    183.800110
# India                       135.100982
# Canada                      113.510961
# United Kingdom               45.534443
# Name: Monthly_exp, dtype: float64

# %%
sns.boxplot(x="CountryLive",y="Monthly_exp",data=fcc1_update)
# Out:
# <AxesSubplot:xlabel='CountryLive', ylabel='Monthly_exp'>

# %% [markdown]
# # now check the outlier in india where

# %%
bol_india=(fcc1_update["CountryLive"]=="India") & (fcc1_update["Monthly_exp"]>=2500)
bol_india
# Out:
# 1        False
# 2        False
# 6        False
# 15       False
# 16       False
#          ...
# 18107    False
# 18111    False
# 18113    False
# 18130    False
# 18156    False
# Length: 3913, dtype: bool

# %%
fcc1_update[bol_india]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1728   24.0               0.0             NaN                NaN          NaN
# 1755   20.0               0.0             NaN                NaN          NaN
# 7989   28.0               0.0             NaN                NaN          NaN
# 8126   22.0               0.0             NaN                NaN          NaN
# 13398  19.0               0.0             NaN                NaN          NaN
# 15587  27.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1728                 NaN             NaN  between 100,000 and 1 million
# 1755                 NaN             NaN            more than 1 million
# 7989                 NaN             NaN  between 100,000 and 1 million
# 8126                 NaN             NaN            more than 1 million
# ...

# %% [markdown]
# **these above 6 row did not understand the serway and they just spend the money , no reson of using money, so we need to remove**

# %%
fcc1_update[bol_india].index
# Out:
# Int64Index([1728, 1755, 7989, 8126, 13398, 15587], dtype='int64')

# %%
fcc1_update.drop(fcc1_update[bol_india].index,inplace=True)
# Out:
# C:\Users\junaid.8646059\Junaid\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fcc1_update.shape
# Out:
# (3907, 137)

# %% [markdown]
# # check outlyer in usa

# %%
bol_usa=(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000)
bol_usa
# Out:
# 1        False
# 2        False
# 6        False
# 15       False
# 16       False
#          ...
# 18107    False
# 18111    False
# 18113    False
# 18130    False
# 18156    False
# Length: 3907, dtype: bool

# %%
fcc1_update[bol_usa]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718    26.0               1.0             0.0                0.0
# 1222   32.0               1.0             0.0                0.0
# 3184   34.0               1.0             1.0                0.0
# 3930   31.0               0.0             NaN                NaN
# 6805   46.0               1.0             1.0                1.0
# 7198   32.0               0.0             NaN                NaN
# 7505   26.0               1.0             0.0                1.0
# 9778   33.0               1.0             0.0                1.0
# 16650  29.0               0.0             NaN                NaN
# 16997  27.0               0.0             NaN                NaN
# 17231  50.0               0.0             NaN                NaN
#
#                                  BootcampName  BootcampRecommend  \
# 718    The Coding Boot Camp at UCLA Extension                1.0
# ...

# %% [markdown]
# ### now we  decide to remove the data that  have 0 bootcamp and belong to usa and exp >=6000

# %%
bol_usa_not_attend=(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000) & (fcc1_update["AttendedBootcamp"]==0) 
bol_usa_not_attend
# Out:
# 1        False
# 2        False
# 6        False
# 15       False
# 16       False
#          ...
# 18107    False
# 18111    False
# 18113    False
# 18130    False
# 18156    False
# Length: 3907, dtype: bool

# %%
fcc1_update[bol_usa_not_attend]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 3930   31.0               0.0             NaN                NaN          NaN
# 7198   32.0               0.0             NaN                NaN          NaN
# 16650  29.0               0.0             NaN                NaN          NaN
# 16997  27.0               0.0             NaN                NaN          NaN
# 17231  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 3930                 NaN             NaN  between 100,000 and 1 million
# 7198                 NaN             NaN            more than 1 million
# 16650                NaN             2.0            more than 1 million
# 16997                NaN             1.0            more than 1 million
# 17231                NaN             2.0              less than 100,000
#
# ...

# %%
fcc1_update[bol_usa_not_attend].index
# Out:
# Int64Index([3930, 7198, 16650, 16997, 17231], dtype='int64')

# %%
fcc1_update.drop(fcc1_update[bol_usa_not_attend].index,inplace=True)
# Out:
# C:\Users\junaid.8646059\Junaid\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
bol_usa_not_attend=(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000) & (fcc1_update["AttendedBootcamp"]==0) 
fcc1_update[bol_usa_not_attend]
# Out:
# Empty DataFrame
# ...

# %%
fcc1_update[(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000)]
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718   26.0               1.0             0.0                0.0
# 1222  32.0               1.0             0.0                0.0
# 3184  34.0               1.0             1.0                0.0
# 6805  46.0               1.0             1.0                1.0
# 7505  26.0               1.0             0.0                1.0
# 9778  33.0               1.0             0.0                1.0
#
#                                 BootcampName  BootcampRecommend  \
# 718   The Coding Boot Camp at UCLA Extension                1.0
# 1222                           The Iron Yard                1.0
# 3184                          We Can Code IT                1.0
# 6805                                Sabio.la                0.0
# 7505                                  Codeup                0.0
# 9778                            Grand Circus                1.0
#
# ...

# %%
pd.options.display.max_columns=None

# %%
fcc1_update[(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000)]
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718   26.0               1.0             0.0                0.0
# 1222  32.0               1.0             0.0                0.0
# 3184  34.0               1.0             1.0                0.0
# 6805  46.0               1.0             1.0                1.0
# 7505  26.0               1.0             0.0                1.0
# 9778  33.0               1.0             0.0                1.0
#
#                                 BootcampName  BootcampRecommend  \
# 718   The Coding Boot Camp at UCLA Extension                1.0
# 1222                           The Iron Yard                1.0
# 3184                          We Can Code IT                1.0
# 6805                                Sabio.la                0.0
# 7505                                  Codeup                0.0
# 9778                            Grand Circus                1.0
#
# ...

# %%
bol_usa_monthly=(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000)
fcc1_update[bol_usa_monthly][["MonthsProgramming","Monthly_exp"]]
# Out:
#       MonthsProgramming   Monthly_exp
# 718                 1.0   8000.000000
# 1222                2.0   6500.000000
# 3184                1.0   9000.000000
# 6805                1.0  15000.000000
# 7505                3.0   6666.666667
# 9778                1.0   8000.000000

# %%
bol_usa_lessthen_3=(fcc1_update["CountryLive"]=="United States of America") & (fcc1_update["Monthly_exp"]>=6000) & (fcc1_update["MonthsProgramming"]<=3) 
fcc1_update[bol_usa_lessthen_3]
#we take monthly subscribtion 59 so, these are the values that attemed bootcamp one month but paid full fee, we need to remove
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718   26.0               1.0             0.0                0.0
# 1222  32.0               1.0             0.0                0.0
# 3184  34.0               1.0             1.0                0.0
# 6805  46.0               1.0             1.0                1.0
# 7505  26.0               1.0             0.0                1.0
# 9778  33.0               1.0             0.0                1.0
#
#                                 BootcampName  BootcampRecommend  \
# 718   The Coding Boot Camp at UCLA Extension                1.0
# 1222                           The Iron Yard                1.0
# 3184                          We Can Code IT                1.0
# 6805                                Sabio.la                0.0
# 7505                                  Codeup                0.0
# 9778                            Grand Circus                1.0
#
# ...

# %%
fcc1_update.drop(fcc1_update[bol_usa_lessthen_3].index,inplace=True)
# Out:
# C:\Users\junaid.8646059\Junaid\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fcc1_update
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
# ...

# %%
sns.boxplot(x="CountryLive",y="Monthly_exp",data=fcc1_update)
# Out:
# <AxesSubplot:xlabel='CountryLive', ylabel='Monthly_exp'>

# %% [markdown]
# # check outlyer in canida

# %%
bol_canada=(fcc1_update["CountryLive"]=="Canada") & (fcc1_update["Monthly_exp"]>4500)
bol_canada
# Out:
# 1        False
# 2        False
# 6        False
# 15       False
# 16       False
#          ...
# 18107    False
# 18111    False
# 18113    False
# 18130    False
# 18156    False
# Length: 3896, dtype: bool

# %%
fcc1_update[bol_canada]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 13659  24.0               1.0             0.0                0.0      Bloc.io
#
#        BootcampRecommend  ChildrenNumber       CityPopulation  \
# 13659                1.0             NaN  more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  CodeEventFCC  \
# 13659                   1.0                   NaN           1.0
#
#        CodeEventGameJam  CodeEventGirlDev  CodeEventHackathons  \
# 13659               NaN               NaN                  NaN
#
#        CodeEventMeetup  CodeEventNodeSchool  CodeEventNone CodeEventOther  \
# 13659              1.0                  NaN            NaN            NaN
#
#        CodeEventRailsBridge  CodeEventRailsGirls  CodeEventStartUpWknd  \
# 13659                   NaN                  NaN                   NaN
#
#        CodeEventWkdBootcamps  CodeEventWomenCode  CodeEventWorkshops  \
# ...

# %%
fcc1_update[bol_canada][["MonthsProgramming","Monthly_exp"]]
#he studies 2months just we remove it
# Out:
#        MonthsProgramming  Monthly_exp
# 13659                2.0       5000.0

# %%
fcc1_update.drop(fcc1_update[bol_canada].index,inplace=True)
# Out:
# C:\Users\junaid.8646059\Junaid\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fcc1_update
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
# ...

# %%
sns.boxplot(x="CountryLive",y="Monthly_exp",data=fcc1_update)
# Out:
# <AxesSubplot:xlabel='CountryLive', ylabel='Monthly_exp'>

# %%
fcc1_update.groupby("CountryLive")["Monthly_exp"].mean()
# Out:
# CountryLive
# Canada                       93.065400
# India                        65.758763
# United Kingdom               45.534443
# United States of America    142.654608
# Name: Monthly_exp, dtype: float64

# %% [markdown]
# * now data looks better,so we manage inter quatile range,
# * outliyer can not be end, but we need to remove it on the basic of reasons
# * inter quatile range=upper - lower
# * inter quatile range=75%-25%

# %%
iqr = upperperc-lowerperc

iqr*1.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-5bfc983434b0> in <module>
# ----> 1 iqr = upperperc-lowerperc
#       2
#       3 iqr*1.5
#
# NameError: name 'upperperc' is not defined

# %%
upper_out =  upperperc+iqr*1.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-152-6fda9257ce25> in <module>
# ----> 1 upper_out =  upperperc+iqr*1.5
#
# NameError: name 'upperperc' is not defined

# %%
sns.boxplot(x="CountryLive",y="Monthly_exp",data=fcc1_update,whis=200)
#use 1.5 but here no outliyer
# Out:
# <AxesSubplot:xlabel='CountryLive', ylabel='Monthly_exp'>

# %%
fcc1_update.groupby("CountryLive")["Monthly_exp"].mean().sort_values(ascending=False)
# Out:
# CountryLive
# United States of America    142.654608
# Canada                       93.065400
# India                        65.758763
# United Kingdom               45.534443
# Name: Monthly_exp, dtype: float64

# %%
fcc1_update["CountryLive"].value_counts()
# Out:
# United States of America    2920
# India                        457
# United Kingdom               279
# Canada                       239
# Name: CountryLive, dtype: int64

# %%
fcc1_update["CountryLive"].value_counts(normalize=True)
# Out:
# United States of America    0.749679
# India                       0.117330
# United Kingdom              0.071630
# Canada                      0.061361
# Name: CountryLive, dtype: float64

# %% [markdown]
# * one market USA is selected confirm to lunch the e-course
# * india is big market from canada so, we select india
# * USA alone
# * USA (80%), India(10%),canda(10%)
# * USA, Canada
# * USA, India

# %%
sns.boxplot(x = "CountryLive", y ="Monthly_exp", data =  fcc1_update)
plt.title("Comparision", y = 1.05)#y is position of title
plt.xlabel("Countries")
plt.ylabel("spending")
plt.xticks(rotation = 45)
plt.show()
