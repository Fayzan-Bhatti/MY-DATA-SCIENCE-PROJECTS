# %% [markdown]
# * data about the degree awarded to the students
# * all data is in percetage
# * we use line char when data is in order form or in perodic form like year wise 2000,2001,2003 ....

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
location="percent-bachelors-degrees-women-usa.csv"
data=pd.read_csv(location)
data.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
data.tail()
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 37  2007    47.605026     43.100459                 61.4  59.411993
# 38  2008    47.570834     42.711730                 60.7  59.305765
# 39  2009    48.667224     43.348921                 61.0  58.489583
# 40  2010    48.730042     42.066721                 61.3  59.010255
# 41  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 37  49.000459                           62.5              17.6  78.721413
# 38  48.888027                           62.4              17.8  79.196327
# 39  48.840474                           62.8              18.1  79.532909
# 40  48.757988                           62.5              17.6  79.618625
# 41  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    42 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# Year                             0
# Agriculture                      0
# Architecture                     0
# Art and Performance              0
# Biology                          0
# Business                         0
# Communications and Journalism    0
# Computer Science                 0
# Education                        0
# Engineering                      0
# English                          0
# Foreign Languages                0
# Health Professions               0
# Math and Statistics              0
# Physical Sciences                0
# Psychology                       0
# Public Administration            0
# Social Sciences and History      0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    42.000000    42.000000     42.000000            42.000000  42.000000
# mean   1990.500000    33.848165     33.685540            61.100000  49.429864
# std      12.267844    12.552731      9.574057             1.305336  10.087725
# min    1970.000000     4.229798     11.921005            58.600000  29.088363
# 25%    1980.250000    30.840814     28.520709            60.200000  44.311821
# 50%    1990.500000    33.317552     35.994852            61.300000  50.971469
# 75%    2000.750000    45.663953     40.790605            62.000000  58.679194
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  42.000000                      42.000000         42.000000  42.000000
# mean   40.653471                      56.216667         25.809524  76.356236
# ...

# %%
data.describe(include="all")
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    42.000000    42.000000     42.000000            42.000000  42.000000
# mean   1990.500000    33.848165     33.685540            61.100000  49.429864
# std      12.267844    12.552731      9.574057             1.305336  10.087725
# min    1970.000000     4.229798     11.921005            58.600000  29.088363
# 25%    1980.250000    30.840814     28.520709            60.200000  44.311821
# 50%    1990.500000    33.317552     35.994852            61.300000  50.971469
# 75%    2000.750000    45.663953     40.790605            62.000000  58.679194
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  42.000000                      42.000000         42.000000  42.000000
# mean   40.653471                      56.216667         25.809524  76.356236
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
data.shape
# Out:
# (42, 18)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=42, step=1)

# %%
data["Year"].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011], dtype=int64)

# %%
len(data["Year"].unique())
# Out:
# 42

# %% [markdown]
# # when data is order then we use line chart also known as preodic data

# %%
data.plot("Year","Biology")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # bio

# %%
#pandas in not good in visulzation but it is good in analysis so we use matplibs
plt.plot(data["Year"],data["Biology"],label="Women",marker="*")
plt.plot(data["Year"],100-data["Biology"],label="Men",marker="^")
plt.legend() #to active the label we need active legend
plt.title("Bio comparision")
#almost in 1987 the men interest become low in bio
# Out:
# Text(0.5, 1.0, 'Bio comparision')

# %% [markdown]
# # computer science

# %%
plt.plot(data["Year"],data["Computer Science"],label="Women",marker="*")
plt.plot(data["Year"],100-data["Computer Science"],label="Women",marker="*")
plt.legend()

# %% [markdown]
# # now we need to show the bio and computer science both
# * make a single plot to show the mutiple plot
# * plt.figure() whhich is by defalut
# * to increase the size of plot we use figsize inside plt.figure()

# %%
fig=plt.figure(figsize=(2,3))#wxL

#added subplot inside fig
ax1=fig.add_subplot(1,2,1)#Row ,Col,no of plot
ax2=fig.add_subplot(1,2,2)#Row,Col,no of plot

# %%
fig=plt.figure(figsize=(10,6))#wxL

#added subplot inside fig
ax1=fig.add_subplot(1,2,1)#R,C,no of plot
ax2=fig.add_subplot(1,2,2)#R,C,no of plot

ax1.plot(data["Year"],data["Biology"],label="Women",marker="*")
ax1.plot(data["Year"],100-data["Biology"],label="Men",marker="^")
ax1.set_title("Bio")
ax1.legend()

ax2.plot(data["Year"],data["Computer Science"],label="Women",marker="*")
ax2.plot(data["Year"],100-data["Computer Science"],label="Men",marker="^")
ax2.set_title("CS")
ax2.legend()



plt.show()

# %%
data.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %% [markdown]
# # 3 categories

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 
             'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 
                 'Art and Performance', 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 
              'Education', 'Agriculture','Business', 'Architecture']

# %% [markdown]
# * total number of plots we need in one land , for this we can count them
# * we need to show the each list vertical not horizontal due to space issue
# * plots we horizontally in matplotlib
# * plots arrangement
# * 01 02 03
# * 04 05 06
# * 07 08 09
# * 10 11 12
# * 13 14 15
# * 16 17 18

# %%
len(stem_cats)+len(lib_arts_cats)+len(other_cats)
# Out:
# 17

# %%
fig=plt.figure(figsize=(15,12))
ax1=fig.add_subplot(6,3,1)

# %%
fig=plt.figure(figsize=(15,12))
ax1=fig.add_subplot(6,3,1)

for i in range(0,16,3):
    print(i+1)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3):
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data["Biology"],label="Women",marker="*")

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3):
    start=int(i/3)
    print(start)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3): # 17 plot
    start_i=int(i/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data[stem_cats[start_i]],label="Women",marker="*")
    ax.plot(data["Year"],100-data[stem_cats[start_i]],label="Men",marker="^")
    ax.set_title(stem_cats[start_i])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_i==5:
        ax.tick_params(labelbottom=True)
    ax.legend()

        
#///////////////////////////////////////////////

for j in range(1,16,3): # 17 plot
    start_j=int(j/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,j+1)
    ax.plot(data["Year"],data[lib_arts_cats[start_j]],label="Women",marker="*")
    ax.plot(data["Year"],100-data[lib_arts_cats[start_j]],label="Men",marker="^")
    ax.set_title(lib_arts_cats[start_j])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_j==4:
        ax.tick_params(labelbottom=True) 
    ax.legend()


#///////////////////////////////////////////////

for k in range(2,18,3): # 17 plot
    start_k=int(k/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,k+1)
    ax.plot(data["Year"],data[other_cats[start_k]],label="Women",marker="*")
    ax.plot(data["Year"],100-data[other_cats[start_k]],label="Men",marker="^")
    ax.set_title(other_cats[start_k])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_k==5:
        ax.tick_params(labelbottom=True) 
    ax.legend()


plt.show()

# %% [markdown]
# # legents as labelling

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3): # 17 plot
    start_i=int(i/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data[stem_cats[start_i]])
    ax.plot(data["Year"],100-data[stem_cats[start_i]])
    ax.set_title(stem_cats[start_i])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    ax.spines["left"].set_visible("True")
    
    if start_i==5:
        ax.tick_params(labelbottom=True)
    
    ax.axhline(50,alpha=.25)
    
    if i==0:
        ax.text(2008,78,"Women")
        ax.text(2008,25,"Man")
    elif i==5:
        ax.text(2007,7,"Women")
        ax.text(2007,90,"Man")

        
#///////////////////////////////////////////////

for j in range(1,16,3): # 17 plot
    start_j=int(j/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,j+1)
    ax.plot(data["Year"],data[lib_arts_cats[start_j]])
    ax.plot(data["Year"],100-data[lib_arts_cats[start_j]])
    ax.set_title(lib_arts_cats[start_j])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_j==4:
        ax.tick_params(labelbottom=True) 



#///////////////////////////////////////////////

for k in range(2,18,3): # 17 plot
    start_k=int(k/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,k+1)
    ax.plot(data["Year"],data[other_cats[start_k]])
    ax.plot(data["Year"],100-data[other_cats[start_k]])
    ax.set_title(other_cats[start_k])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_k==5:
        ax.tick_params(labelbottom=True) 
    


plt.show()

# %% [markdown]
# # line width

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3): # 17 plot
    start_i=int(i/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data[stem_cats[start_i]],linewidth=3)
    ax.plot(data["Year"],100-data[stem_cats[start_i]],linewidth=3)
    ax.set_title(stem_cats[start_i])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    ax.spines["left"].set_visible("True")
    
    if start_i==5:
        ax.tick_params(labelbottom=True)
    
    ax.axhline(50,alpha=.25)
    
    if i==0:
        ax.text(2008,78,"Women")
        ax.text(2008,25,"Man")
    elif i==5:
        ax.text(2007,7,"Women")
        ax.text(2007,90,"Man")

        
#///////////////////////////////////////////////

for j in range(1,16,3): # 17 plot
    start_j=int(j/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,j+1)
    ax.plot(data["Year"],data[lib_arts_cats[start_j]])
    ax.plot(data["Year"],100-data[lib_arts_cats[start_j]])
    ax.set_title(lib_arts_cats[start_j])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_j==4:
        ax.tick_params(labelbottom=True) 



#///////////////////////////////////////////////

for k in range(2,18,3): # 17 plot
    start_k=int(k/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,k+1)
    ax.plot(data["Year"],data[other_cats[start_k]])
    ax.plot(data["Year"],100-data[other_cats[start_k]])
    ax.set_title(other_cats[start_k])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_k==5:
        ax.tick_params(labelbottom=True) 
    

plt.show()

# %% [markdown]
# # colors

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3): # 17 plot
    start_i=int(i/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data[stem_cats[start_i]],linewidth=3,color="green")
    ax.plot(data["Year"],100-data[stem_cats[start_i]],linewidth=3)
    ax.set_title(stem_cats[start_i])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    ax.spines["left"].set_visible("True")
    
    if start_i==5:
        ax.tick_params(labelbottom=True)
    
    ax.axhline(50,alpha=.25)
    
    if i==0:
        ax.text(2008,78,"Women")
        ax.text(2008,25,"Man")
    elif i==5:
        ax.text(2007,7,"Women")
        ax.text(2007,90,"Man")

        
#///////////////////////////////////////////////

for j in range(1,16,3): # 17 plot
    start_j=int(j/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,j+1)
    ax.plot(data["Year"],data[lib_arts_cats[start_j]])
    ax.plot(data["Year"],100-data[lib_arts_cats[start_j]])
    ax.set_title(lib_arts_cats[start_j])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_j==4:
        ax.tick_params(labelbottom=True) 



#///////////////////////////////////////////////

for k in range(2,18,3): # 17 plot
    start_k=int(k/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,k+1)
    ax.plot(data["Year"],data[other_cats[start_k]])
    ax.plot(data["Year"],100-data[other_cats[start_k]])
    ax.set_title(other_cats[start_k])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_k==5:
        ax.tick_params(labelbottom=True) 
    

plt.show()

# %% [markdown]
# # saving data

# %%
fig=plt.figure(figsize=(15,12))

for i in range(0,16,3): # 17 plot
    start_i=int(i/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,i+1)
    ax.plot(data["Year"],data[stem_cats[start_i]])
    ax.plot(data["Year"],100-data[stem_cats[start_i]])
    ax.set_title(stem_cats[start_i])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    ax.spines["left"].set_visible("True")
    
    if start_i==5:
        ax.tick_params(labelbottom=True)
    
    ax.axhline(50,alpha=.25)
    
    if i==0:
        ax.text(2008,78,"Women")
        ax.text(2008,25,"Man")
    elif i==5:
        ax.text(2007,7,"Women")
        ax.text(2007,90,"Man")

        
#///////////////////////////////////////////////

for j in range(1,16,3): # 17 plot
    start_j=int(j/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,j+1)
    ax.plot(data["Year"],data[lib_arts_cats[start_j]])
    ax.plot(data["Year"],100-data[lib_arts_cats[start_j]])
    ax.set_title(lib_arts_cats[start_j])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_j==4:
        ax.tick_params(labelbottom=True) 



#///////////////////////////////////////////////

for k in range(2,18,3): # 17 plot
    start_k=int(k/3)#i=0,3,6,9,12,15
    ax=fig.add_subplot(6,3,k+1)
    ax.plot(data["Year"],data[other_cats[start_k]])
    ax.plot(data["Year"],100-data[other_cats[start_k]])
    ax.set_title(other_cats[start_k])
    ax.set_xlim(1970,2012)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100]) # this is junk data, we need to remove
    ax.tick_params(bottom=False, labelbottom=False) # remove the ticks
    for value in ax.spines.values():# will give u dictionay of 4 values with keys , left right bottom top
        value.set_visible(False)
    
    if start_k==5:
        ax.tick_params(labelbottom=True) 
    

fig.savefig("Compairsion.pdf")
#plt.savefig("Compairsion.pdf")
plt.show()

# %% [markdown]
# # Train data

# %% [markdown]
# * data is about the train accident data to check the saft regulation
# * SibSp means hasband or wife
# * Parch means parent and childern
# * Embarked mean stop , station

# %%
tdata=pd.read_csv("train.csv")
tdata.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns

# %% [markdown]
# this laibairy is build on matplotlib but used for conditional ploting
# if u hve not order data and not category data then histogram is used, histogram is made on continous data

# %% [markdown]
# # bins or class intervals

# %%
tdata["Age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
tdata["Age"].value_counts(bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: Age, dtype: int64

# %%
sns.FacetGrid(tdata,col="Survived").map(plt.hist,"Age")

# %%
sns.FacetGrid(tdata,col="Survived").map(sns.distplot,"Age")
plt.show()
# Out:
# C:\Users\junaid.8646059\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\junaid.8646059\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(tdata,col="Survived").map(sns.kdeplot,"Age")
plt.show()

# %%
sns.FacetGrid(tdata,col="Survived").map(sns.kdeplot,"Age",shade=True)
plt.show()

# %%
sns.FacetGrid(tdata,col="Survived",row="Pclass").map(sns.kdeplot,"Age",shade=True)
plt.show()

# %% [markdown]
# **in class three there survie more people**

# %%
sns.FacetGrid(tdata,col="Survived",row="Pclass",hue="Sex").map(sns.kdeplot,"Age",shade=True)
plt.show()

# %%
sns.FacetGrid(tdata,col="Survived",row="Pclass",hue="Sex").map(sns.kdeplot,"Age",shade=True)
plt.legend()
plt.show()

# %%
sns.FacetGrid(tdata,col="Survived",row="Pclass",hue="Sex").map(sns.kdeplot,"Age",shade=True)
plt.show()
